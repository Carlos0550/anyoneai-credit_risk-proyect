# %% [markdown]
# ### *EDA For Datasets(XLS) and TXT files*

# %%
import os
from download_and_extract.download_files import start_download
from download_and_extract.extract_zip_files import start_extract_files

start_download()
start_extract_files()
# Out:
# Descargando credit-data-2010/LeaderBoard_Data.zip a /home/carlos/Escritorio/Credit_Risk_ANYONEAI/src/datasets/LeaderBoard_Data.zip
# Descargando credit-data-2010/Leaderboard_Submission_Example.zip a /home/carlos/Escritorio/Credit_Risk_ANYONEAI/src/datasets/Leaderboard_Submission_Example.zip
# Descargando credit-data-2010/PAKDD-2010 training data.zip a /home/carlos/Escritorio/Credit_Risk_ANYONEAI/src/datasets/PAKDD-2010 training data.zip
# Descargando credit-data-2010/PAKDD2010_Leaderboard_Submission_Example.txt a /home/carlos/Escritorio/Credit_Risk_ANYONEAI/src/datasets/PAKDD2010_Leaderboard_Submission_Example.txt
# Descargando credit-data-2010/PAKDD2010_Modeling_Data.txt a /home/carlos/Escritorio/Credit_Risk_ANYONEAI/src/datasets/PAKDD2010_Modeling_Data.txt
# Descargando credit-data-2010/PAKDD2010_Prediction_Data.txt a /home/carlos/Escritorio/Credit_Risk_ANYONEAI/src/datasets/PAKDD2010_Prediction_Data.txt
# ...

# %%
from parse_files.xls_analyzer import analyze_xls_file
from parse_files.file_utils import convert_all_txt_to_csv

analyze_xls_file()
convert_all_txt_to_csv()
